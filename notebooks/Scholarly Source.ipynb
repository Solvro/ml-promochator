# %%
from scholarly import scholarly

author_name = "Maciej Piasecki"
search_query = scholarly.search_author(author_name)
first_author_result = next(search_query)
first_author_result
# Out:
# {'container_type': 'Author',
#  'filled': [],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'nU_W9XwAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nU_W9XwAAAAJ',
#  'name': 'Maciej Piasecki',
#  'affiliation': 'Wroclaw University of Science and Technology',
#  'email_domain': '@pwr.wroc.pl',
#  'interests': ['Computational Linguistics',
#   'Natural Language Processing',
#   'Human-Computer Interaction',
#   'Artificial Intelligence',
#   'Language Technology'],
#  'citedby': 2935}

# %% [markdown]
# `fill` method retrieves more information

# %%
author = scholarly.fill(first_author_result)
author
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'nU_W9XwAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nU_W9XwAAAAJ',
#  'name': 'Maciej Piasecki',
#  'affiliation': 'Wroclaw University of Science and Technology',
#  'email_domain': '@pwr.wroc.pl',
#  'interests': ['Computational Linguistics',
#   'Natural Language Processing',
#   'Human-Computer Interaction',
#   'Artificial Intelligence',
#   'Language Technology'],
#  'citedby': 2923,
#  'citedby5y': 1301,
#  'hindex': 24,
#  'hindex5y': 14,
#  'i10index': 81,
#  'i10index5y': 28,
#  'cites_per_year': {2006: 18,
#   2007: 50,
#   2008: 89,
#   2009: 95,
#   2010: 112,
#   2011: 118,
#   2012: 131,
#   2013: 186,
#   2014: 155,
#   2015: 123,
#   2016: 153,
#   2017: 154,
#   2018: 170,
#   2019: 195,
#   2020: 130,
#   2021: 199,
#   2022: 115,
#   2023: 342,
#   2024: 313},
#  'coauthors': [{'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'hc3Zj7UAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Marek Maziarz',
#    'affiliation': 'Wrocław University of Science and Technology'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'pulMdOUAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Bartosz Broda',
#    'affiliation': 'Vertex Rage Studio'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'Sv_zNIgAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Radosław Ramocki',
#    'affiliation': 'Politechnika Wrocławska'}],
#  'publications': [{'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ChatGPT: Jack of all trades, master of none',
#     'pub_year': '2023',
#     'citation': 'Information Fusion 99, 101861, 2023'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:Aul-kAQHnToC',
#    'num_citations': 410,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2600515932282922845',
#    'cites_id': ['2600515932282922845']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A wordnet from the ground up',
#     'pub_year': '2009',
#     'citation': 'Oficyna Wydawnicza Politechniki Wrocławskiej, 2009'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:9yKSN-GCB0IC',
#    'num_citations': 237,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1531489357328541294',
#    'cites_id': ['1531489357328541294']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Polish tagger TaKIPI: Rule based construction and optimisation',
#     'pub_year': '2007',
#     'citation': 'Task quarterly 11 (1-2), 151-167, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:u-x6o8ySG0sC',
#    'num_citations': 123,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5561767314288601308',
#    'cites_id': ['5561767314288601308']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'plwordnet 3.0–a comprehensive lexical-semantic resource',
#     'pub_year': '2016',
#     'citation': 'Proceedings of COLING 2016, the 26th International Conference on …, 2016'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:uJ-U7cs_P_0C',
#    'num_citations': 82,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4249483796373510158',
#    'cites_id': ['4249483796373510158']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Approaching plWordNet 2.0',
#     'pub_year': '2012',
#     'citation': 'Proceedings of 6th International Global Wordnet Conference, The Global …, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:rO6llkc54NcC',
#    'num_citations': 77,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7404412784566623273',
#    'cites_id': ['7404412784566623273']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Words, concepts and relations in the construction of Polish WordNet',
#     'pub_year': '2008',
#     'citation': 'Proceedings of GWC, 162-177, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:u5HHmVD_uO8C',
#    'num_citations': 76,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3265303876870996139',
#    'cites_id': ['3265303876870996139']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A strategy of mapping Polish Wordnet onto Princeton Wordnet',
#     'pub_year': '2012',
#     'citation': 'Proceedings of COLING 2012: Posters, 1039-1048, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:UxriW0iASnsC',
#    'num_citations': 60,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=89673870156158179',
#    'cites_id': ['89673870156158179']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A large wordnet-based sentiment lexicon for Polish',
#     'pub_year': '2015',
#     'citation': 'Proceedings of the international conference recent advances in natural …, 2015'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:0KyAp5RtaNEC',
#    'num_citations': 49,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9207861182824879436',
#    'cites_id': ['9207861182824879436']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The chicken-and-egg problem in wordnet design: synonymy, synsets and constitutive relations',
#     'pub_year': '2013',
#     'citation': 'Language Resources and Evaluation 47, 769-796, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:uWQEDVKXjbEC',
#    'num_citations': 45,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7103770995742081971',
#    'cites_id': ['7103770995742081971']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'An open stylometric system based on multilevel text analysis',
#     'pub_year': '2017',
#     'citation': 'Cognitive Studies, 2017'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:BUYA1_V_uYcC',
#    'num_citations': 34,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16331138342740185021',
#    'cites_id': ['16331138342740185021']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automatic selection of heterogeneous syntactic features in semantic similarity of Polish nouns',
#     'pub_year': '2007',
#     'citation': 'International Conference on Text, Speech and Dialogue, 99-106, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:d1gkVwhDpl0C',
#    'num_citations': 34,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17551427689575497676',
#    'cites_id': ['17551427689575497676']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Resource and service centres as the backbone for a sustainable service infrastructure',
#     'pub_year': '2010',
#     'citation': 'Seventh conference on International Language Resources and Evaluation [LREC …, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:mlAyqtXpCwEC',
#    'num_citations': 32,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1309477816871792241',
#    'cites_id': ['1309477816871792241']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Beyond the transfer-and-merge wordnet construction: plWordNet and a comparison with WordNet',
#     'pub_year': '2013',
#     'citation': 'Proceedings of the international conference recent advances in natural …, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:tS2w5q8j5-wC',
#    'num_citations': 31,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9699649452799817040',
#    'cites_id': ['9699649452799817040']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WordNetLoom: a WordNet development system integrating form-based and graph-based perspectives',
#     'pub_year': '2013',
#     'citation': 'International Journal of Data Mining, Modelling and Management 5 (3), 210-232, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:u_35RYKgDlwC',
#    'num_citations': 31,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4110269927316304034',
#    'cites_id': ['4110269927316304034']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Semantic similarity measure of Polish nouns based on linguistic features',
#     'pub_year': '2007',
#     'citation': 'Business Information Systems: 10th International Conference, BIS 2007 …, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:UeHWp8X0CEIC',
#    'num_citations': 31,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7348541079057839514',
#    'cites_id': ['7348541079057839514']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Word sense disambiguation based on large scale Polish CLARIN heterogeneous lexical resources',
#     'pub_year': '2015',
#     'citation': 'Cognitive Studies| Études cognitives, 269-292, 2015'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:N5tVd3kTz84C',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7222983873869588474',
#    'cites_id': ['7222983873869588474']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Rank-based transformation in measuring semantic relatedness',
#     'pub_year': '2009',
#     'citation': 'Advances in Artificial Intelligence: 22nd Canadian Conference on Artificial …, 2009'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:kNdYIx-mwKoC',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4853789229914254352',
#    'cites_id': ['4853789229914254352']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Recognition of structured collocations in an inflective language',
#     'pub_year': '2007',
#     'citation': 'Proceedings of the International Multiconference on Computer Science and …, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:W7OEmFMy1HYC',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12822592871634386036',
#    'cites_id': ['12822592871634386036']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'plWordNet 4.1-a linguistically motivated, corpus-based bilingual resource',
#     'pub_year': '2019',
#     'citation': 'Proceedings of the 10th Global Wordnet Conference, 353-362, 2019'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:rmuvC79q63oC',
#    'num_citations': 29,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16515151252407124969',
#    'cites_id': ['16515151252407124969']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WordNet2Vec: Corpora agnostic word vectorization method',
#     'pub_year': '2019',
#     'citation': 'Neurocomputing 326, 141-150, 2019'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:_Re3VWB3Y0AC',
#    'num_citations': 29,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2667975040954749083',
#    'cites_id': ['2667975040954749083']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Polish WordNet on a shoestring',
#     'pub_year': '2007',
#     'citation': 'Proceedings of Biannual Conference of the Society for Computational …, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:2osOgNQ5qMEC',
#    'num_citations': 27,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16482152007280678989',
#    'cites_id': ['16482152007280678989']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Neuro-symbolic models for sentiment analysis',
#     'pub_year': '2022',
#     'citation': 'International conference on computational science, 667-681, 2022'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:HtS1dXgVpQUC',
#    'num_citations': 25,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11792841244901095810',
#    'cites_id': ['11792841244901095810']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Extended similarity test for the evaluation of semantic similarity functions',
#     'pub_year': '2007',
#     'citation': 'Proceedings of the 3rd Language and Technology Conference 10, 05-07, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:qjMakFHDy7sC',
#    'num_citations': 25,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16983604464676197383',
#    'cites_id': ['16983604464676197383']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Parallel, massive processing in SuperMatrix: A general tool for distributional semantic analysis of corpora',
#     'pub_year': '2013',
#     'citation': 'International Journal of Data Mining, Modelling and Management 5 (1), 1-19, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ZeXyd9-uunAC',
#    'num_citations': 24,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16511604359095663727',
#    'cites_id': ['16511604359095663727']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'SuperMatrix: a general tool for lexical semantic knowledge acquisition',
#     'pub_year': '2008',
#     'citation': '2008 International Multiconference on Computer Science and Information …, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:YsMSGLbcyi4C',
#    'num_citations': 24,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1248583363122751852',
#    'cites_id': ['1248583363122751852']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'plWordNet as a basis for large emotive lexicons of Polish',
#     'pub_year': '2017',
#     'citation': 'Proceedings of Human Language Technologies as a Challenge for Computer …, 2017'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:4MWp96NkSFoC',
#    'num_citations': 23,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5967557559556716901',
#    'cites_id': ['5967557559556716901']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Corpus-based Semantic Relatedness for the Construction of Polish WordNet.',
#     'pub_year': '2008',
#     'citation': 'LREC, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:zYLM7Y9cAGgC',
#    'num_citations': 23,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11529330512536091810',
#    'cites_id': ['11529330512536091810']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Hand-written and automatically extracted rules for Polish tagger',
#     'pub_year': '2006',
#     'citation': 'Text, Speech and Dialogue: 9th International Conference, TSD 2006, Brno …, 2006'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:eQOLeE2rZwMC',
#    'num_citations': 23,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11505577205226274279',
#    'cites_id': ['11505577205226274279']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Multilingual and language-agnostic recognition of emotions, valence and arousal in large-scale multi-domain text reviews',
#     'pub_year': '2019',
#     'citation': 'Language and Technology Conference, 214-231, 2019'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:hCrLmN-GePgC',
#    'num_citations': 22,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8522334710535518131',
#    'cites_id': ['8522334710535518131']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'PlWordNet as the cornerstone of a toolkit of lexico-semantic resources',
#     'pub_year': '2014',
#     'citation': 'Proceedings of the seventh global wordnet conference, 304-312, 2014'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:eflP2zaiRacC',
#    'num_citations': 22,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=391793149155216842',
#    'cites_id': ['391793149155216842']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Semantic relations among adjectives in Polish WordNet 2.0: a new relation set, discussion and evaluation',
#     'pub_year': '2012',
#     'citation': 'Cognitive Studies| Études cognitives, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:CHSYGLWDkRkC',
#    'num_citations': 22,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16706323283355680357',
#    'cites_id': ['16706323283355680357']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Semantic relations between verbs in polish wordnet 2.0',
#     'pub_year': '2011',
#     'citation': 'Cognitive Studies| Études cognitives, 2011'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:RHpTSmoSYBkC',
#    'num_citations': 22,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9689712222795641372',
#    'cites_id': ['9689712222795641372']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Polish morphological guesser based on a statistical a tergo index',
#     'pub_year': '2007',
#     'citation': 'Proceedings of the International Multiconference on Computer Science and …, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:MXK_kJrjxJIC',
#    'num_citations': 21,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3074259072344585849',
#    'cites_id': ['3074259072344585849']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'User-driven language technology infrastructure—the case of Clarin-PL',
#     'pub_year': '2014',
#     'citation': 'Proceedings of the Ninth Language Technologies Conference. Ljubljana, Slovenia, 2014'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:WA5NYHcadZ8C',
#    'num_citations': 19,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=820308817876938034',
#    'cites_id': ['820308817876938034']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards a set of general purpose morphosyntactic tools for Polish',
#     'pub_year': '2008',
#     'citation': 'Proceedings of Intelligent Information Systems, Zakopane, Poland, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:Tyk-4Ss8FVUC',
#    'num_citations': 19,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=147759985769056563',
#    'cites_id': ['147759985769056563']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A procedural definition of multi-word lexical units',
#     'pub_year': '2015',
#     'citation': 'Proceedings of the international conference recent advances in natural …, 2015'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:VL0QpB8kHFEC',
#    'num_citations': 18,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15684117596982852193',
#    'cites_id': ['15684117596982852193']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Semantic relations among nouns in Polish WordNet grounded in lexicographic and semantic tradition',
#     'pub_year': '2011',
#     'citation': 'Cognitive Studies| Études cognitives, 2011'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:j3f4tGmQtD8C',
#    'num_citations': 18,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15688207547042139903',
#    'cites_id': ['15688207547042139903']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Effective architecture of the Polish tagger',
#     'pub_year': '2006',
#     'citation': 'Text, Speech and Dialogue: 9th International Conference, TSD 2006, Brno …, 2006'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:IjCSPb-OGe4C',
#    'num_citations': 18,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1307353934292858750',
#    'cites_id': ['1307353934292858750']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Multitask personalized recognition of emotions evoked by textual content',
#     'pub_year': '2022',
#     'citation': '2022 IEEE International Conference on Pervasive Computing and Communications …, 2022'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:dBIO0h50nwkC',
#    'num_citations': 17,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18446334546543976371',
#    'cites_id': ['18446334546543976371']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Distributionally extended network-based word sense disambiguation in semantic clustering of Polish texts',
#     'pub_year': '2014',
#     'citation': 'IERI Procedia 10, 38-44, 2014'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:5ugPr518TE4C',
#    'num_citations': 17,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15657977997363460496',
#    'cites_id': ['15657977997363460496']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Recognition of Polish Derivational Relations Based on Supervised Learning Scheme.',
#     'pub_year': '2012',
#     'citation': 'LREC, 916-922, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:_xSYboBqXhAC',
#    'num_citations': 17,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17949536797870533722',
#    'cites_id': ['17949536797870533722']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Sense equivalence in plWordNet to Princeton WordNet mapping',
#     'pub_year': '2019',
#     'citation': 'International Journal of Lexicography 32 (3), 296-325, 2019'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ruyezt5ZtCIC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=842360783814964721',
#    'cites_id': ['842360783814964721']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automatic prompt system in the process of mapping plWordNet on Princeton WordNet',
#     'pub_year': '2013',
#     'citation': 'Cognitive Studies| Études cognitives,(13), 123-141, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:geHnlv5EZngC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13748707424352274393',
#    'cites_id': ['13748707424352274393']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards word sense disambiguation of Polish',
#     'pub_year': '2008',
#     'citation': '2008 International Multiconference on Computer Science and Information …, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:4TOpqqG69KYC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6178824183411089510',
#    'cites_id': ['6178824183411089510']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WordnetLoom–A multilingual wordnet editing system focused on graph-based presentation',
#     'pub_year': '2018',
#     'citation': 'Proceedings of the 9th Global Wordnet Conference, 190-199, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:Z5m8FVwuT1cC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=138285951346721559',
#    'cites_id': ['138285951346721559']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Open dataset for development of polish question answering systems',
#     'pub_year': '2013',
#     'citation': 'Proceedings of the 6th Language & Technology Conference: Human Language …, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:D_sINldO8mEC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11680631731391304482',
#    'cites_id': ['11680631731391304482']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Structure annotation in the polish corpus of suicide notes',
#     'pub_year': '2011',
#     'citation': 'Text, Speech and Dialogue: 14th International Conference, TSD 2011, Pilsen …, 2011'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:YFjsv_pBGBYC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8064252409492755357,5500342678878288610',
#    'cites_id': ['8064252409492755357', '5500342678878288610']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automatic acquisition of wordnet relations by the morpho-syntactic patterns extracted from the corpora in Polish',
#     'pub_year': '2008',
#     'citation': '2008 International Multiconference on Computer Science and Information …, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:WF5omc3nYNoC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13003887648068225961',
#    'cites_id': ['13003887648068225961']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Reductionistic, tree and rule based tagger for Polish',
#     'pub_year': '2006',
#     'citation': 'Intelligent Information Processing and Web Mining: Proceedings of the …, 2006'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:Y0pCki6q_DkC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16914922041019156060',
#    'cites_id': ['16914922041019156060']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Classifier-based polarity propagation in a wordnet',
#     'pub_year': '2018',
#     'citation': 'Proceedings of the Eleventh International Conference on Language Resources …, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:e_rmSamDkqQC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18370859215038216378',
#    'cites_id': ['18370859215038216378']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Open stylometric system WebSty: Integrated language processing, analysis and visualisation',
#     'pub_year': '2018',
#     'citation': 'CMST 24 (1), 43-58, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:PoWvk5oyLR8C',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15957999695317823379',
#    'cites_id': ['15957999695317823379']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Evaluation of baseline information retrieval for polish open-domain question answering system',
#     'pub_year': '2013',
#     'citation': 'Proceedings of the International Conference Recent Advances in Natural …, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:JoZmwDi-zQgC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2936983353186510496,17703326204636305248',
#    'cites_id': ['2936983353186510496', '17703326204636305248']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A preliminary noun phrase chunker for Polish',
#     'pub_year': '2010',
#     'citation': 'Proceedings of the Intelligent Information Systems, 169-180, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:hFOr9nPyWt4C',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8600208433089061882',
#    'cites_id': ['8600208433089061882']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Lexical units as the centrepiece of a wordnet',
#     'pub_year': '2008',
#     'citation': 'Proceedings of the 16th International Conference Intelligent Information …, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:0EnyYjriUFMC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13450759139107331224',
#    'cites_id': ['13450759139107331224']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Classification-based filtering of semantic relatedness in hypernymy extraction',
#     'pub_year': '2008',
#     'citation': 'Advances in Natural Language Processing: 6th International Conference, GoTAL …, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:_FxGoFyzp5QC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17881989336838126432',
#    'cites_id': ['17881989336838126432']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Emotion norms for 6000 Polish word meanings with a direct mapping to the Polish wordnet',
#     'pub_year': '2021',
#     'citation': 'Behavior Research Methods, 1-16, 2021'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:IUKN3-7HHlwC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9849792671812456871',
#    'cites_id': ['9849792671812456871']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Context-sensitive sentiment propagation in wordnet',
#     'pub_year': '2018',
#     'citation': 'Proceedings of the 9th global wordnet conference, 329-334, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:gsN89kCJA0AC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1542242296918074421',
#    'cites_id': ['1542242296918074421']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Ruled-based, Interlingual Motivated Mapping of plWordNet onto SUMO Ontology.',
#     'pub_year': '2014',
#     'citation': 'LREC, 4351-4358, 2014'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:q3oQSFYPqjQC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16319297640175318834',
#    'cites_id': ['16319297640175318834']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Statistical proper name recognition in Polish economic texts',
#     'pub_year': '2011',
#     'citation': 'Control and Cybernetics 40 (2), 393-418, 2011'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:SeFeTyx0c_EC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1842448563155970830',
#    'cites_id': ['1842448563155970830']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Evaluating LexCSD—a weakly-supervised method on improved semantically annotated corpus in a large scale experiment',
#     'pub_year': '2010',
#     'citation': 'Proceedings of Intelligent Information Systems, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:Wp0gIr-vW9MC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10995961522292831609',
#    'cites_id': ['10995961522292831609']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Correction of medical handwriting OCR based on semantic similarity',
#     'pub_year': '2007',
#     'citation': 'Intelligent Data Engineering and Automated Learning-IDEAL 2007: 8th …, 2007'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:5nxA0vEk-isC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16477390668381756802',
#    'cites_id': ['16477390668381756802']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Multiclassifier approach to tagging of Polish',
#     'pub_year': '2006',
#     'citation': 'Proceedings of 1st International Symposium Advances in Artificial …, 2006'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:qxL8FJ1GzNcC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17087077887507812522',
#    'cites_id': ['17087077887507812522']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Wordnet-based evaluation of large distributional models for polish',
#     'pub_year': '2018',
#     'citation': 'Proceedings of the 9th Global Wordnet Conference, 229-238, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:kuK5TVdYjLIC',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12179576736899854300',
#    'cites_id': ['12179576736899854300']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Extraction of the multi-word lexical units in the perspective of the wordnet expansion',
#     'pub_year': '2015',
#     'citation': 'Proceedings of the International Conference Recent Advances in Natural …, 2015'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ye4kPcJQO24C',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6463912305383643117',
#    'cites_id': ['6463912305383643117']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Rich set of features for proper name recognition in polish texts',
#     'pub_year': '2012',
#     'citation': 'Security and Intelligent Information Systems: International Joint …, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:dfsIfKJdRG4C',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16695435714432291467',
#    'cites_id': ['16695435714432291467']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Toward plWordNet 2.0',
#     'pub_year': '2010',
#     'citation': 'Principles, construction and application of multilingual wordnets …, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:HDshCWvjkbEC',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8233616014399270180',
#    'cites_id': ['8233616014399270180']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Semi-supervised word sense disambiguation based on weakly controlled sense induction',
#     'pub_year': '2009',
#     'citation': '2009 International Multiconference on Computer Science and Information …, 2009'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:aqlVkmm33-oC',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=271772204345085292',
#    'cites_id': ['271772204345085292']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards emotive annotation in plWordNet 4.0',
#     'pub_year': '2018',
#     'citation': 'Proceedings of the 9th Global Wordnet Conference, 153-162, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:bz8QjSJIRt4C',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15495249469821994194',
#    'cites_id': ['15495249469821994194']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Literary Exploration Machine A Web-Based Application for Textual Scholars.',
#     'pub_year': '2017',
#     'citation': 'CLARIN Annual Conference, 128-144, 2017'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:LI9QrySNdTsC',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13997686584477658774',
#    'cites_id': ['13997686584477658774']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'plwordnet 3.0–almost there',
#     'pub_year': '2016',
#     'citation': 'Proceedings of the 8th Global WordNet Conference (GWC), 292-301, 2016'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:HbR8gkJAVGIC',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5787785313915043120',
#    'cites_id': ['5787785313915043120']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Evaluation method for automated wordnet expansion',
#     'pub_year': '2012',
#     'citation': 'Security and Intelligent Information Systems: International Joint …, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:cFHS6HbyZ2cC',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=615406109546006063',
#    'cites_id': ['615406109546006063']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'This is the way: designing and compiling LEPISZCZE, a comprehensive NLP benchmark for Polish',
#     'pub_year': '2022',
#     'citation': 'Advances in Neural Information Processing Systems 35, 21805-21818, 2022'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:yFnVuubrUp4C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4248229270344393819',
#    'cites_id': ['4248229270344393819']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Propagation of emotions, arousal and polarity in WordNet using Heterogeneous Structured Synset Embeddings',
#     'pub_year': '2019',
#     'citation': 'Proceedings of the 10th Global Wordnet Conference, 336-341, 2019'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:_axFR9aDTf0C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=431335221056351848',
#    'cites_id': ['431335221056351848']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A weakly supervised word sense disambiguation for Polish using rich lexical resources',
#     'pub_year': '2019',
#     'citation': 'Poznan Studies in Contemporary Linguistics 55 (2), 339-365, 2019'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ClCfbGk0d_YC',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7472494947015574196',
#    'cites_id': ['7472494947015574196']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Implementation of the verb model in plWordNet 4.0',
#     'pub_year': '2018',
#     'citation': 'Proceedings of the 9th Global Wordnet Conference, 113-122, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:TIZ-Mc8IlK0C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11474418236458820682',
#    'cites_id': ['11474418236458820682']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards CLARIN-PL LTC digital research platform for: Depositing, processing, analyzing and visualizing language data',
#     'pub_year': '2018',
#     'citation': 'Reliability and Statistics in Transportation and Communication: Selected …, 2018'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ILKRHgRFtOwC',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3707544660617334220',
#    'cites_id': ['3707544660617334220']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Mapping wordnets from the perspective of inter-lingual equivalence',
#     'pub_year': '2017',
#     'citation': 'Cognitive Studies, 2017'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:URolC5Kub84C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=839611302524952250',
#    'cites_id': ['839611302524952250']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automated generation of derivative relations in the Wordnet expansion perspective',
#     'pub_year': '2012',
#     'citation': 'Proceedings of 6th International Global Wordnet Conference, 273-280, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:OU6Ihb5iCvQC',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4037464912597181248',
#    'cites_id': ['4037464912597181248']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Study on named entity recognition for Polish based on hidden Markov models',
#     'pub_year': '2010',
#     'citation': 'Text, Speech and Dialogue: 13th International Conference, TSD 2010, Brno …, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:r0BpntZqJG4C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16087117949114465553',
#    'cites_id': ['16087117949114465553']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Named Entity Recognition in the Domain of Polish Stock Exchange Reports',
#     'pub_year': '2010',
#     'citation': 'Proceedings of the 18th International Conference Intelligent Information …, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:hC7cP41nSMkC',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7046109354304001634',
#    'cites_id': ['7046109354304001634']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Experiments in clustering documents for automatic acquisition of lexical semantic networks for Polish',
#     'pub_year': '2008',
#     'citation': 'Proc. of the 16th Int. Conf. Intelligent Information Systems, 203-212, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:UebtZRa9Y70C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6129144994711090456',
#    'cites_id': ['6129144994711090456']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards Revised System of Verb Wordnet Relations for Polish.',
#     'pub_year': '2017',
#     'citation': 'LDK Workshops, 174-187, 2017'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:uc_IGeMz5qoC',
#    'num_citations': 9,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2075536487139019199',
#    'cites_id': ['2075536487139019199']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WordnetLoom: a graph-based visual wordnet development framework',
#     'pub_year': '2010',
#     'citation': 'Proceedings of the International Multiconference on Computer Science and …, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:lSLTfruPkqcC',
#    'num_citations': 9,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12147000792889390660',
#    'cites_id': ['12147000792889390660']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
# ...
#    'bib': {'title': 'Utemeljevanje sloWNeta na korpusnih podatkih',
#     'pub_year': '2013',
#     'citation': 'Slovenščina 2.0: empirične, aplikativne in interdisciplinarne raziskave 1 (2 …, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:foquWX3nUaYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Pytania i odpowiedzi z serwisu wikipedyjnego" Czy wiesz", wersja 1.1',
#     'pub_year': '2013',
#     'citation': 'Wrocław University of Technology, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:VLnqNzywnoUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Question Answering dataset-“Czy wiesz”',
#     'pub_year': '2013',
#     'citation': 'Wroclaw University of Technology, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:olpn-zPbct0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': '3rd international workshop on advances in semantic information retrieval',
#     'pub_year': '2013',
#     'citation': '2013 Federated Conference on Computer Science and Information Systems …, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:hkOj_22Ku90C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Biologiczne systemy wczesnego ostrzegania',
#     'pub_year': '2013',
#     'citation': 'Wodociągi-Kanalizacja, 18-19, 2013'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:vRqMK49ujn8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Fextor',
#     'pub_year': '2012',
#     'citation': 'Wrocław University of Technology, 2012'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:bnK-pcrLprsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ChunkRel WS',
#     'pub_year': '2011',
#     'citation': 'Wrocław University of Technology, 2011'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:J-pR_7NvFogC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WordnetLoom',
#     'pub_year': '2011',
#     'citation': 'Wrocław University of Technology, 2011'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:wbdj-CoPYUoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WordNet',
#     'pub_year': '2010',
#     'citation': 'Wrocław University of Technology, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:HE397vMXCloC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Resource and Service Centres as the Backbone for a Sustainable Service Infrastructure',
#     'pub_year': '2010',
#     'citation': "Seventh conference on International Language Resources and Evaluation (LREC'10), 2010"},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:0N-VGjzr574C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Systemy łączności radiowej i monitoringu telewizyjnego',
#     'pub_year': '2010',
#     'citation': 'Przegląd Telekomunikacyjny+ Wiadomości Telekomunikacyjne, 1707-1711, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:p2g8aNsByqUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automated extraction of lexical meanings from Polish corpora: potentialities and limitations',
#     'pub_year': '2010',
#     'citation': 'Cognitive Studies| Études cognitives, 177-202, 2010'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:k_IJM867U9cC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'plWordNet (Słowosieć)',
#     'pub_year': '2008',
#     'citation': 'Research Institute for Artificial Intelligence, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:Mojj43d5GZwC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards semi-automatic extraction of lexical semantics relations for Polish',
#     'pub_year': '2008',
#     'citation': 'International Journal of Intelligent Information and Database Systems 2 (3 …, 2008'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:M05iB0D1s5AC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Słowosieć---polski wordnet',
#     'pub_year': '2007',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:PELIpwtuRlgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Logo-the modular conversational agent understanding Polish',
#     'pub_year': '2005',
#     'citation': '5th International Conference on Intelligent Systems Design and Applications …, 2005'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ldfaerwXgEUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Conceptual modeling of user interface in object oriented methodologies',
#     'pub_year': '2005',
#     'citation': 'Foundations of Computing and Decision Sciences 30 (1), 17-27, 2005'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:b1wdh0AR-JQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Deep Parser for Free English Texts Based on Machine Learning with Limited Resources',
#     'pub_year': '2005',
#     'citation': 'Intelligent Information Processing and Web Mining: Proceedings of the …, 2005'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:isC4tDSrTZIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': '218 Information Modelling and Knowledge Bases XII H. Jaakkola et al.(Eds.) IOS Press, 2001',
#     'pub_year': '2001',
#     'citation': 'Information Modelling and Knowledge Bases XII 12, 218, 2001'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:artPoR2Yc-kC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Modelling Basic Multimedia Notions in UML',
#     'pub_year': '2001',
#     'citation': 'FRONTIERS IN ARTIFICIAL INTELLIGENCE AND APPLICATIONS 67, 218, 2001'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:ns9cj8rnVeAC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'MG Nadkarni:" Basic Ergodic Theory"',
#     'pub_year': '1999',
#     'citation': 'CONTROL AND CYBERNETICS 28, 375-376, 1999'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:nb7KW1ujOQ8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Modelowanie otoczenia robota mobilnego za pomocą map różnicowych',
#     'pub_year': '1998',
#     'citation': 'Pomiary Automatyka Robotyka 2 (7-8), 16-20, 1998'},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:35N4QoGY0k4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automated Mapping of Polish Proper Names on plWordNet Hypernymy Structure',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:SpbeaW3--B0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'WebSty–an Open Stylometric System based on Multilevel Text Analysis',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:-FonjvnnhkoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Polish-English wordnet–a new resource and its potential for translators',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:p__nRnzSRKYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Challenges for Wordnets', 'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:vDijr-p_gm4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Machine Exploration of Secondary Literature with Literary Exploration Machine',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:epqYDVWIO7EC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Wordnet-based Similarity Measure for Polish Short Texts',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:JQOojiI6XY0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'plWordNet 2.3 emo and enWordNet 1.0: a demo',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:UHK10RUVsp4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Weaving sloWNet using window-based co-occurence features',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:mvPsJ3kp5DgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Polish WordNet on a Shoestring', 'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:sSrBHYA8nusC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards a concept of lexical unit for a wordnet',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:B3FOqHPlNUQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards a truly bilingual wordnet-plWordNet 2.0.',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:l7t_Zn2s7bgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Toward Integrated Lexico-Semantic Language Technology for Polish',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:zA6iFVUQeVQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Opis relacji leksykalno-semantycznych w Słowosieci 2.0. Czasownik Seria: PRE nr 5',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:3s1wT3WcHBgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Some Aspects of Semantic Representation of Polish Determiners',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:pqnbT2bcN3wC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The Multidimensional Approach to Quantification and Reference in the Noun Phrase',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:70eg2SAEIzsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Koncepcja obiektowego modelu znaczenia polskiej frazy nominalnej.',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:NaGl4SEjCO4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Linguistically Annotated Data Sets for the Polish English Machine Translation System.',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:RGFaLdJalmkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Automatic Acquisition of Semantic Similarity as a Small Step towards Uncovering the Hidden Structure.',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:NMxIlDl6LWMC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Modelling Basic Multimedia Notions in UML',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:M3NEmzRMIkIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Compositional, Variable Free, Binding Free and Structure Oriented Discourse Interpretation',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:TFP_iSt0sucC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Towards computational verification of Self-organising Logic of Structures',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:bEWYMUwI8FkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A MULTI-LEVEL ARCHITECTURE FOR RECOGNITION OF POLISH HANDWRITTEN MEDICAL TEXTS',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:iH-uZ7U-co4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ZASTOSOWANIE ALGORYTMU GENETYCZNEGO DO KONSTRUKCJI FUNKCJI OCENIAJĄCEJ W GRZE OTHELLO',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'nU_W9XwAAAAJ:4JMBOYKVnBMC',
#    'num_citations': 0}],
#  'public_access': {'available': 17, 'not_available': 2}}

# %% [markdown]
# author's publications

# %%
len(author['publications'])
# Out:
# 293

# %% [markdown]
# Here we only have some brief info about the given publication

# %%
first_publication = author['publications'][0]
first_publication
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'ChatGPT: Jack of all trades, master of none',
#   'pub_year': '2023',
#   'citation': 'Information Fusion 99, 101861, 2023'},
#  'filled': False,
#  'author_pub_id': 'nU_W9XwAAAAJ:Aul-kAQHnToC',
#  'num_citations': 410,
#  'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2600515932282922845',
#  'cites_id': ['2600515932282922845']}

# %%
first_publication_filled = scholarly.fill(first_publication)
first_publication_filled
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'ChatGPT: Jack of all trades, master of none',
#   'pub_year': 2023,
#   'citation': 'Information Fusion 99, 101861, 2023',
#   'author': 'Jan Kocoń and Igor Cichecki and Oliwier Kaszyca and Mateusz Kochanek and Dominika Szydło and Joanna Baran and Julita Bielaniewicz and Marcin Gruza and Arkadiusz Janz and Kamil Kanclerz and Anna Kocoń and Bartłomiej Koptyra and Wiktoria Mieleszczenko-Kowszewicz and Piotr Miłkowski and Marcin Oleksy and Maciej Piasecki and Łukasz Radliński and Konrad Wojtasik and Stanisław Woźniak and Przemysław Kazienko',
#   'journal': 'Information Fusion',
#   'volume': '99',
#   'pages': '101861',
#   'publisher': 'Elsevier',
#   'abstract': 'OpenAI has released the Chat Generative Pre-trained Transformer (ChatGPT) and revolutionized the approach in artificial intelligence to human-model interaction. The first contact with the chatbot reveals its ability to provide detailed and precise answers in various areas. Several publications on ChatGPT evaluation test its effectiveness on well-known natural language processing (NLP) tasks. However, the existing studies are mostly non-automated and tested on a very limited scale. In this work, we examined ChatGPT’s capabilities on 25 diverse analytical NLP tasks, most of them subjective even to humans, such as sentiment analysis, emotion recognition, offensiveness, and stance detection. In contrast, the other tasks require more objective reasoning like word sense disambiguation, linguistic acceptability, and question answering. We also evaluated GPT-4 model on five selected subsets of NLP tasks. We …'},
#  'filled': True,
#  'author_pub_id': 'nU_W9XwAAAAJ:Aul-kAQHnToC',
#  'num_citations': 410,
#  'citedby_url': '/scholar?hl=en&cites=2600515932282922845',
#  'cites_id': ['2600515932282922845'],
#  'pub_url': 'https://www.sciencedirect.com/science/article/pii/S156625352300177X',
#  'url_related_articles': '/scholar?oi=bibs&hl=en&q=related:Xad3WHbjFiQJ:scholar.google.com/',
#  'cites_per_year': {2023: 156, 2024: 251}}

# %% [markdown]
# Here we have multiple authors!

# %%
first_publication_filled['bib']['author']
# Out:
# 'Jan Kocoń and Igor Cichecki and Oliwier Kaszyca and Mateusz Kochanek and Dominika Szydło and Joanna Baran and Julita Bielaniewicz and Marcin Gruza and Arkadiusz Janz and Kamil Kanclerz and Anna Kocoń and Bartłomiej Koptyra and Wiktoria Mieleszczenko-Kowszewicz and Piotr Miłkowski and Marcin Oleksy and Maciej Piasecki and Łukasz Radliński and Konrad Wojtasik and Stanisław Woźniak and Przemysław Kazienko'

# %% [markdown]
# The abstract is not full.

# %%
first_publication_filled['bib']['abstract']
# Out:
# 'OpenAI has released the Chat Generative Pre-trained Transformer (ChatGPT) and revolutionized the approach in artificial intelligence to human-model interaction. The first contact with the chatbot reveals its ability to provide detailed and precise answers in various areas. Several publications on ChatGPT evaluation test its effectiveness on well-known natural language processing (NLP) tasks. However, the existing studies are mostly non-automated and tested on a very limited scale. In this work, we examined ChatGPT’s capabilities on 25 diverse analytical NLP tasks, most of them subjective even to humans, such as sentiment analysis, emotion recognition, offensiveness, and stance detection. In contrast, the other tasks require more objective reasoning like word sense disambiguation, linguistic acceptability, and question answering. We also evaluated GPT-4 model on five selected subsets of NLP tasks. We …'

# %%
def get_author_publications(author_name):
    # 'affiliation' should be 'Wroclaw University of Science and Technology' or similiar
    search_query = scholarly.search_author(author_name)
    if not search_query:
        return None 
    first_author_result = next(search_query)
    author = scholarly.fill(first_author_result)
    return author['publications']

# %%
def structure_publications(publications):
    structured_publications = []
    for publication in publications:
        filled_pub = scholarly.fill(publication)
        if 'abstract' in filled_pub['bib']:
            structured_publications.append({'abstract' : filled_pub['bib']['abstract'], 'title': filled_pub['bib']['title'], 'author': filled_pub['bib']['author']})
        
    return structured_publications

# %%
mp_pubs = get_author_publications('Maciej Piasecki')
mp_structured_publications = structure_publications(mp_pubs)

# %%
mp_structured_publications[0]
# Out:
# {'abstract': 'OpenAI has released the Chat Generative Pre-trained Transformer (ChatGPT) and revolutionized the approach in artificial intelligence to human-model interaction. The first contact with the chatbot reveals its ability to provide detailed and precise answers in various areas. Several publications on ChatGPT evaluation test its effectiveness on well-known natural language processing (NLP) tasks. However, the existing studies are mostly non-automated and tested on a very limited scale. In this work, we examined ChatGPT’s capabilities on 25 diverse analytical NLP tasks, most of them subjective even to humans, such as sentiment analysis, emotion recognition, offensiveness, and stance detection. In contrast, the other tasks require more objective reasoning like word sense disambiguation, linguistic acceptability, and question answering. We also evaluated GPT-4 model on five selected subsets of NLP tasks. We …',
#  'title': 'ChatGPT: Jack of all trades, master of none',
#  'author': 'Jan Kocoń and Igor Cichecki and Oliwier Kaszyca and Mateusz Kochanek and Dominika Szydło and Joanna Baran and Julita Bielaniewicz and Marcin Gruza and Arkadiusz Janz and Kamil Kanclerz and Anna Kocoń and Bartłomiej Koptyra and Wiktoria Mieleszczenko-Kowszewicz and Piotr Miłkowski and Marcin Oleksy and Maciej Piasecki and Łukasz Radliński and Konrad Wojtasik and Stanisław Woźniak and Przemysław Kazienko'}

# %%
from scholarly import ProxyGenerator

# Using proxy to prevent the IP from being blocked
# Searching authors by organization, works for authors added to the organization but doesn't include everyone
def search_authors_by_organization(org_id):
    pg = ProxyGenerator()
    pg.FreeProxies()
    scholarly.use_proxy(pg)

    search_query = scholarly.search_author_by_organization(org_id)
    authors=[author for author in search_query]

    return authors

organization_id = 6200813508511872715

author_names = search_authors_by_organization(organization_id)
author_names
# Out:
# [{'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'hnzxVlgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=hnzxVlgAAAAJ',
#   'name': 'Rafał Weron',
#   'affiliation': 'Wrocław University of Science and Technology (Politechnika Wrocławska), Poland',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Energy Forecasting',
#    'Energy Analytics',
#    'Energy Economics',
#    'Computational Finance',
#    'Energy Finance'],
#   'citedby': 17241},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'HlQok7EAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=HlQok7EAAAAJ',
#   'name': 'Wladyslaw Walkowiak',
#   'affiliation': 'Emerytowany profesor chemii, Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['hydrometallurgy',
#    'ion flotation',
#    'liquid membranes',
#    'solvent extraction',
#    'environmental chemistry'],
#   'citedby': 16977},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '4fHBmMUAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4fHBmMUAAAAJ',
#   'name': 'Katarzyna Chojnacka',
#   'affiliation': 'Politechnika Wrocławska / Wroclaw University of Technology / Faculty of Chemistry',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['biosorption', 'bioaccumulation', 'algae', 'microelements'],
#   'citedby': 16590},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'pV8Y62cAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=pV8Y62cAAAAJ',
#   'name': 'Jan Misiewicz',
#   'affiliation': 'Profesor of Physics Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 10288},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'xja9IUgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xja9IUgAAAAJ',
#   'name': 'Michal Wozniak',
#   'affiliation': 'Wroclaw University of Science and Technology (Politechnika Wrocławska)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['machine learning',
#    'pattern recognition',
#    'classifier ensemble',
#    'data stream mining'],
#   'citedby': 8542},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '2kxCCw4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=2kxCCw4AAAAJ',
#   'name': 'Marcin Drag',
#   'affiliation': 'Professor, Department of Chemical Biology and Bioimaging, Wroclaw University of …',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['unnatural amino acids',
#    'proteases',
#    'substrate specificity',
#    'chemical biology',
#    'activity based probes'],
#   'citedby': 8403},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '8gPv7BQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=8gPv7BQAAAAJ',
#   'name': 'Aleksander Weron',
#   'affiliation': 'Wrocław University of Technology, Poland',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Stochastic Modeling',
#    'Stochastic Processes',
#    'Heavy-tailed Models',
#    'Anomalous Diffusion',
#    'Financial Mathematics'],
#   'citedby': 7102},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'z6o7_iQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=z6o7_iQAAAAJ',
#   'name': 'Rafal Zdunek',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['nieujemna faktoryzacja macierzy i tensorów'],
#   'citedby': 6952},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'Ts2C370AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Ts2C370AAAAJ',
#   'name': 'Grzegorz Soboń',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Fiber lasers',
#    'ultrafast lasers',
#    'nonlinear optics',
#    'frequency combs'],
#   'citedby': 6335},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'v6Ne_ToAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=v6Ne_ToAAAAJ',
#   'name': 'D. Robert Iskander',
#   'affiliation': 'Wroclaw University of Science and Technology (Politechnika Wrocławska)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['biomedical optics',
#    'OCT',
#    'corneal topography',
#    'biomedical signal processing'],
#   'citedby': 6324},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'cxLgNccAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=cxLgNccAAAAJ',
#   'name': 'Przemysław Kazienko',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['machine learning',
#    'affective computing',
#    'NLP',
#    'wearables',
#    'social networks'],
#   'citedby': 6165},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'U6H85q8AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=U6H85q8AAAAJ',
#   'name': 'Wieslaw A. Dudek',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Mathematics'],
#   'citedby': 5967},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'jg-PYHYAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=jg-PYHYAAAAJ',
#   'name': 'Zbigniew Leonowicz',
#   'affiliation': 'Professor, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['electrical engineering',
#    'signal processing',
#    'power systems',
#    'energy',
#    'renewables'],
#   'citedby': 5940},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'rztfaGQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=rztfaGQAAAAJ',
#   'name': 'WA Sokalski',
#   'affiliation': 'prof. chemii  Politechnika Wroclawska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['chemia kwantowa'],
#   'citedby': 4523},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'cnLc7u4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=cnLc7u4AAAAJ',
#   'name': 'Krzysztof Walkowiak',
#   'affiliation': 'Wroclaw University of Science and Technology (Politechnika Wrocławska)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Optical Networks',
#    'Computer Networks',
#    'Optimization',
#    'Algorithms'],
#   'citedby': 4248},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'MwBXY1UAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=MwBXY1UAAAAJ',
#   'name': 'Łukasz Sadowski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['concrete',
#    'adhesion',
#    'surface metrology',
#    'non-destructive testing',
#    'artificial intelligence'],
#   'citedby': 3879},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'KZvYNncAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=KZvYNncAAAAJ',
#   'name': 'Agnieszka Wylomanska',
#   'affiliation': 'Associate Professor, Faculty of Pure and Applied Mathematics, Wroclaw University of …',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['stochastic processes',
#    'heavy-tailed distributions',
#    'statistical analysis',
#    'time series modeling'],
#   'citedby': 3861},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'nA6Rs5YAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nA6Rs5YAAAAJ',
#   'name': 'Jan Iżykowski, prof. dr hab. inż.; IEEE Life Fellow',
#   'affiliation': 'Politechnika Wrocławska / Wroclaw University of Science and Technology - Professor …',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['power system protection',
#    'fault location',
#    'power system transients'],
#   'citedby': 3717},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'DVPmEIQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=DVPmEIQAAAAJ',
#   'name': 'Teodor Gotszalk',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 3603},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'yBM-YE4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=yBM-YE4AAAAJ',
#   'name': 'Jozef Oleksyszyn',
#   'affiliation': 'profesor Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['biotechnologia drug design'],
#   'citedby': 3229},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'udu_2kAAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=udu_2kAAAAAJ',
#   'name': 'Dorota Kuchta',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 3206},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'qmX546sAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=qmX546sAAAAJ',
#   'name': 'Lech Madeyski',
#   'affiliation': 'Wroclaw University of Science and Technology (Politechnika Wrocławska), Poland',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['software engineering',
#    'empirical software engineering',
#    'AI/ML',
#    'data science',
#    'reproducible research'],
#   'citedby': 3132},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'lfaatzMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=lfaatzMAAAAJ',
#   'name': 'Piotr Mlynarz',
#   'affiliation': 'Wrocław University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 2940},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'PYDJCS4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=PYDJCS4AAAAJ',
#   'name': 'Piotr Jamróz',
#   'affiliation': 'Wroclaw University of Science and Technology Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['cold plasma',
#    'plasma chemistry',
#    'microplasma',
#    'atomic spectrometry',
#    'plasma medicine'],
#   'citedby': 2828},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '8oDibeQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=8oDibeQAAAAJ',
#   'name': 'Adam Sieradzki',
#   'affiliation': 'Politechnika Wrocławska (Wrocław University of Science and Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['dielectric spectroscopy',
#    'thermal analysis',
#    'ferroics',
#    'multiferroics',
#    'hybrid compounds'],
#   'citedby': 2758},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'IEkBieIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=IEkBieIAAAAJ',
#   'name': 'Tomasz Kurzynowski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['SLM', 'EBM', 'CAD', 'badania materiałowe'],
#   'citedby': 2738},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'eAiblTwAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=eAiblTwAAAAJ',
#   'name': 'Zbigniew Gronostajski',
#   'affiliation': 'Wrocław University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 2637},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'v7XBBAEAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=v7XBBAEAAAAJ',
#   'name': 'Pawel Zielinski',
#   'affiliation': 'Department of Fundamentals of Computer Science, Wrocław University of Technology …',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Robust optimization',
#    'computational complexity',
#    'approximation algorithms'],
#   'citedby': 2574},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'xcQ6FugAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xcQ6FugAAAAJ',
#   'name': 'Dina Czajczyńska',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['piroliza', 'oczyszczanie gazów'],
#   'citedby': 2378},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'GOoaHHEAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=GOoaHHEAAAAJ',
#   'name': 'Tomasz Kajdanowicz',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Data Science', 'Machine Learning', 'Representation Learning'],
#   'citedby': 2375},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'RRH2yM8AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=RRH2yM8AAAAJ',
#   'name': 'Bogdan Boduszek',
#   'affiliation': 'Profesor nauk chemicznych, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['filozofia', 'turystyka', 'fotografia'],
#   'citedby': 2206},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'blU6g94AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=blU6g94AAAAJ',
#   'name': 'halina podbielska',
#   'affiliation': 'Politechnika Wroclawska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['inżynieria biomedyczna',
#    'biomedical engineering',
#    'optics',
#    'physics',
#    'biomaterials'],
#   'citedby': 2205},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'PGRjojAAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=PGRjojAAAAAJ',
#   'name': 'Halina Kwasnicka',
#   'affiliation': 'Professor, computer science, Politechnika Wroclawska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['artificial intelligence',
#    'soft computing',
#    'data mining',
#    'images analysis'],
#   'citedby': 2204},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'z3HMHlAAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=z3HMHlAAAAAJ',
#   'name': 'Jakub Nowotarski',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 2199},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'Qd201Y0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Qd201Y0AAAAJ',
#   'name': 'Leszek Jurdziak, DSc, PhD',
#   'affiliation': 'associate prof. at Wroclaw University of Technology, former Head of Industrial- and …',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['applied mathematics',
#    'mining engineering',
#    'mineral economics',
#    'geoeconomics',
#    'industrial economics'],
#   'citedby': 2183},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'yseuD_EAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=yseuD_EAAAAJ',
#   'name': 'Jerzy Jedrzejewski',
#   'affiliation': 'Profesor inżynierii wytwarzania, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['mechanika i budowa maszyn', 'inteligentne obrabiarki'],
#   'citedby': 2144},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'FE1BprcAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=FE1BprcAAAAJ',
#   'name': 'Daria Podstawczyk',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 2134},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'nCeP2SwAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nCeP2SwAAAAJ',
#   'name': 'Ambroziak Andrzej',
#   'affiliation': 'Profesor Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 2096},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'nuPgVLoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nuPgVLoAAAAJ',
#   'name': 'Sai Shiva Krishna Prasad Vurukonda',
#   'affiliation': 'Faculty of Chemistry, Politechnika Wroclawska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Plant-Microbe Interactions',
#    'PGPR',
#    'Bioformulations',
#    'Microbial Biotechnology',
#    'Microbial Ecology'],
#   'citedby': 2061},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'BZH4U34AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=BZH4U34AAAAJ',
#   'name': 'Grzegorz Lesiuk, PhD. DSc. Eng., Associate Professor with Habilitation,',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['fracture mechanics',
#    'fatigue',
#    'fatigue fracture',
#    'failure analysis'],
#   'citedby': 1996},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ccBo37MAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ccBo37MAAAAJ',
#   'name': 'Piotr Kowalczyk',
#   'affiliation': 'Wrocław University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Dynamical Systems', 'Biomechanics'],
#   'citedby': 1897},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'w5q7rkIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=w5q7rkIAAAAJ',
#   'name': 'Dawid Skrzypczak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['biomasa', 'nawozy'],
#   'citedby': 1894},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'qmMEM94AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=qmMEM94AAAAJ',
#   'name': 'Tadeusz A. Przylibski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['isotopes',
#    'meteorites',
#    'groundwater',
#    'radon',
#    'extraterrestrial resources'],
#   'citedby': 1826},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'GU45uPAAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=GU45uPAAAAAJ',
#   'name': 'Stanisław Lochyński',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1801},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'AWsCqRMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=AWsCqRMAAAAJ',
#   'name': 'Jerzy Kaleta',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['experimental mechanics',
#    'strentgh of materials',
#    'fatigue',
#    'smart materials',
#    'hydrogen storage'],
#   'citedby': 1766},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'B6b9IDQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=B6b9IDQAAAAJ',
#   'name': 'Joanna Janczura',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 1703},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ns-gWMMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ns-gWMMAAAAJ',
#   'name': 'Ewaryst Rafajlowicz',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['identification',
#    'control',
#    'neural nets',
#    'pattern recognition',
#    'image processing'],
#   'citedby': 1697},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '4_ads5kAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4_ads5kAAAAJ',
#   'name': 'Tyll Krüger',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['complex systems', 'dynamical systems', 'networks'],
#   'citedby': 1674},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'cRMcZWYAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=cRMcZWYAAAAJ',
#   'name': 'Grzegorz Izydorczyk',
#   'affiliation': 'Adiunkt, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1655},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'IB4As5sAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=IB4As5sAAAAJ',
#   'name': 'Paulina Kasperkiewicz',
#   'affiliation': 'Division of Bioorganic Chemistry, Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['proteases',
#    'substrate specificity',
#    'chemical biology_confocal microscopy',
#    'activity based probes',
#    'neutrophil serine proteases'],
#   'citedby': 1652},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'mCMaig4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=mCMaig4AAAAJ',
#   'name': 'Zdzisław Bubnicki',
#   'affiliation': 'Professor, Wrocław University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Control theory - System identification …'],
#   'citedby': 1616},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '1kshqgwAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=1kshqgwAAAAJ',
#   'name': 'Małgorzata Komorowska',
#   'affiliation': 'profesor n. biologicznych, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['żwiatłoterapia', 'krew'],
#   'citedby': 1433},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '6yuY28UAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=6yuY28UAAAAJ',
#   'name': 'Jerzy Jasienko',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1388},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'kDpRDDcAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kDpRDDcAAAAJ',
#   'name': 'Tadeusz Smolnicki',
#   'affiliation': 'Politechnika Wrocławska Wydział Mechaniczny',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 1374},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'xVnXxoIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xVnXxoIAAAAJ',
#   'name': 'Sylwia Werbińska-Wojciechowska',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1343},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ou6ziXoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ou6ziXoAAAAJ',
#   'name': 'Marian Jureczko',
#   'affiliation': 'Computer Science, Wroclaw Univeristy of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Computer Science', 'Software Engineering'],
#   'citedby': 1322},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'np2ShdoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=np2ShdoAAAAJ',
#   'name': 'Katarzyna Maciejowska',
#   'affiliation': 'Wrocław University of Technology, Poland',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Energy economics',
#    'time series',
#    'panel data',
#    'econometric theory'],
#   'citedby': 1289},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'CojWJ90AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=CojWJ90AAAAJ',
#   'name': 'Karol Malecha',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['LTCC',
#    'microsystem',
#    'microfluidics',
#    'lab-on-chip',
#    'fabrication'],
#   'citedby': 1284},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'cvOeJIUAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=cvOeJIUAAAAJ',
#   'name': 'Jerzy Czmochowski',
#   'affiliation': 'Politechnika Wrocławska Wydział Mechaniczny',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['dynamika maszyn', 'metoda elementów skończonych'],
#   'citedby': 1274},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'nXRc5NoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nXRc5NoAAAAJ',
#   'name': 'Ryszard Poprawski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1267},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'tIccLRIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=tIccLRIAAAAJ',
#   'name': 'Bartosz Kaźmierczak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1234},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'hFInCgUAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=hFInCgUAAAAJ',
#   'name': 'Henryk Maciejewski',
#   'affiliation': 'Wroclaw Univ. of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Machine learning',
#    'bioinformatics',
#    'OoD detection',
#    'parallel processing',
#    'reliability'],
#   'citedby': 1222},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'd-R09XoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=d-R09XoAAAAJ',
#   'name': 'Marderos Ara Sayegh',
#   'affiliation': 'Wrocław University of Technology (WUST)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['… - District heating -Solar - Heat pipes - Heat …'],
#   'citedby': 1200},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'YyJNkCQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=YyJNkCQAAAAJ',
#   'name': 'Ryszard Błażej',
#   'affiliation': 'Politechnika wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Taśmy przenośnikowe',
#    'złącza taśmowe',
#    'ndt diagnostyka',
#    'trwałość taśm i połączeń',
#    'analiza obrazu'],
#   'citedby': 1198},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'zeWjCRwAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=zeWjCRwAAAAJ',
#   'name': 'Paweł P. Zagożdżon',
#   'affiliation': 'doktor, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1194},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'K25CQ8UAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=K25CQ8UAAAAJ',
#   'name': 'Ewa Matczak-Jon',
#   'affiliation': 'prof chemii Politechnika Wroclawska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['chemia koordynacyjna'],
#   'citedby': 1192},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'iZ8-BicAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=iZ8-BicAAAAJ',
#   'name': 'Czeslaw T. Kowalski',
#   'affiliation': 'Professot ofElectrical Engineering, Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Electrical machines and drives',
#    'Diagnostics',
#    'Artificial Intelligence'],
#   'citedby': 1160},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'DonrOa8AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=DonrOa8AAAAJ',
#   'name': 'Wlodzimierz Szczepaniak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['procesy termiczne',
#    'gospodarka odpadami',
#    'metalurgia chemiczna'],
#   'citedby': 1129},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'lExHm8wAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=lExHm8wAAAAJ',
#   'name': 'Lydzba Dariusz',
#   'affiliation': 'Profesor budownictwa, Politechnika Wroclawska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 1122},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'XydgaasAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=XydgaasAAAAJ',
#   'name': 'Tomasz Nowakowski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['logistyka', 'niezawodność', 'transport', 'system'],
#   'citedby': 1101},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'JVO46DgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=JVO46DgAAAAJ',
#   'name': 'Rafal Kowalczyk',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['organic chemistry'],
#   'citedby': 1060},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '12JwJMEAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=12JwJMEAAAAJ',
#   'name': 'Sebastian Kraszewski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['molecular dynamics of biological structures'],
#   'citedby': 1033},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ZKbJl-kAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ZKbJl-kAAAAJ',
#   'name': 'Andrzej T. Kowal',
#   'affiliation': 'Chemistry Department, Wrocław University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Computational Chemistry',
#    'Spectroscopy',
#    'IR',
#    'Raman',
#    'MCD'],
#   'citedby': 1016},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'AZJgCXoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=AZJgCXoAAAAJ',
#   'name': 'Jan Magott',
#   'affiliation': 'Professor of Computer Science, Wroclaw University of Technology ',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Computational intelligence', 'safety', 'Petri nets'],
#   'citedby': 983},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'YD4QTRYAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=YD4QTRYAAAAJ',
#   'name': 'Róża Goścień',
#   'affiliation': 'PhD Dsc @ Wroclaw University of Science and Technology (Politechnika Wrocławska)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['networks',
#    'survivability',
#    'modeling and optimization',
#    'algorithms',
#    'artificial intelligence'],
#   'citedby': 979},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '6tYiitoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=6tYiitoAAAAJ',
#   'name': 'Wojciech Puła',
#   'affiliation': 'Profesor, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Structural reliability',
#    'geotechnics',
#    'probabilistic methods'],
#   'citedby': 978},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'eDrvktQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=eDrvktQAAAAJ',
#   'name': 'Sławomir Czarnecki',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['civil engineering',
#    'concrete',
#    'artificial intelligence',
#    'waste management',
#    'ndt'],
#   'citedby': 975},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '4HDQ1b0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4HDQ1b0AAAAJ',
#   'name': 'Tomasz Walkowiak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['NLP'],
#   'citedby': 961},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'XWQ9DvgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=XWQ9DvgAAAAJ',
#   'name': 'Hubert Zarzycki',
#   'affiliation': 'Wroclaw University of Science and Technology (Politechnika Wrocławska)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 931},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'AjA0TN4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=AjA0TN4AAAAJ',
#   'name': 'Marcin Winnicki',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 927},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '_UCdzEMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=_UCdzEMAAAAJ',
#   'name': 'Pavlo Krot',
#   'affiliation': 'Politechnika Wrocławska, Faculty of Geoengineering, Mining and Geology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Mining machines',
#    'rolling mills',
#    'condition monitoring',
#    'dynamics',
#    'vibration diagnostics'],
#   'citedby': 926},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'dskdlPIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=dskdlPIAAAAJ',
#   'name': 'Jakub Obuchowski',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['stochastic modeling',
#    'signal processing',
#    'applied mathematics'],
#   'citedby': 911},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'NvtrlJMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=NvtrlJMAAAAJ',
#   'name': 'Jan Blachowski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['spatial analysis', 'gis', 'mining'],
#   'citedby': 902},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '5VX5_gUAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=5VX5_gUAAAAJ',
#   'name': 'Krzysztof Juszczyszyn',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['social networks', 'semantic web', 'SOA architectures'],
#   'citedby': 897},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'qmZce7UAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=qmZce7UAAAAJ',
#   'name': 'Pawel Kaczmarek',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 855},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '1GsA7FgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=1GsA7FgAAAAJ',
#   'name': 'Paweł Sztonyk',
#   'affiliation': 'Wrocław University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['stochastic processes', 'potential theory', 'semigroups'],
#   'citedby': 846},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '6SzI48UAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=6SzI48UAAAAJ',
#   'name': 'Jaroslaw Filipiak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['biomechanika', 'mechanobiologia', 'inżynieria tkankowa'],
#   'citedby': 821},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'KR0FwKsAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=KR0FwKsAAAAJ',
#   'name': 'jerzy grobelny',
#   'affiliation': 'Politechnika Wrocławska,Wydział Zarządzania',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['zarządzanie',
#    'ergonomia',
#    'inżynieria produkcji',
#    'modelowanie matematyczne'],
#   'citedby': 815},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'f4r4YbMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=f4r4YbMAAAAJ',
#   'name': 'Piotr Sitarek',
#   'affiliation': 'dr inż., Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 804},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '_6MaA5gAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=_6MaA5gAAAAJ',
#   'name': 'Justyna Rybak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['ochrona środowiska'],
#   'citedby': 797},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '3EPLb8wAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=3EPLb8wAAAAJ',
#   'name': 'Zbigniew Michna',
#   'affiliation': 'Wrocław University of Science and Technology, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['stochastic processes',
#    'Levy processes',
#    'Gaussian processes',
#    'risk theory',
#    'supply chain modeling'],
#   'citedby': 788},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'zfJeD14AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=zfJeD14AAAAJ',
#   'name': 'Adam Dominik Szukalski',
#   'affiliation': 'Politechnika Wrocławska, Wydział Chemiczny, Instytut Materiałów Zaawansowanych; …',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['spektroskopia laserowa',
#    'optyka nieliniowa',
#    'materia organiczna',
#    'druk 3D',
#    'fotonika'],
#   'citedby': 785},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ntUQNzIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ntUQNzIAAAAJ',
#   'name': 'Agnieszka Tubis',
#   'affiliation': 'Profesor uczelni, Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['logistics',
#    'transport',
#    'risk management',
#    'supply chain cooperation'],
#   'citedby': 779},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'hUktcbIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=hUktcbIAAAAJ',
#   'name': 'Anna Burduk',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['systemy produkcyjne'],
#   'citedby': 765},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'iYfQ3x0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=iYfQ3x0AAAAJ',
#   'name': 'Eunika Zielony',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 761},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'DjIxn3MAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=DjIxn3MAAAAJ',
#   'name': 'Magdalena Klimek-Ochab',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['biocatalytic capabilities of fungi'],
#   'citedby': 760},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'ooHIYswAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ooHIYswAAAAJ',
#   'name': 'Piotr Jadwiszczak',
#   'affiliation': 'Doktor inżynier, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Niekonwencjonalne i odnawialne źródła …',
#    'nowczesne systemy grzewcze',
#    'układy automatycznej regu'],
#   'citedby': 739},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'F0TKj2UAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=F0TKj2UAAAAJ',
#   'name': 'Leszek Borzemski',
#   'affiliation': 'Professor of Computer Science, Wroclaw University of Technology, Wroclaw, Poland',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Web performance prediction',
#    'Web performance',
#    'Web design',
#    'Web mining',
#    'IoT'],
#   'citedby': 734},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '20b3R1QAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=20b3R1QAAAAJ',
#   'name': 'Dobrucki A.',
#   'affiliation': 'Wrocław University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 718},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'aHfnUP0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=aHfnUP0AAAAJ',
#   'name': 'Janusz Jakubiak',
#   'affiliation': 'Wrocław University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 717},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '4nNaVD4AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4nNaVD4AAAAJ',
#   'name': 'Sylwia Olsztyńska-Janus',
#   'affiliation': 'adiunkt, Katedra Inżynierii Biomedycznej, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['spektroskopia oscylacyjna',
#    'struktury biologiczne',
#    'światłoterapia',
#    'NIR'],
#   'citedby': 716},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '_xDC7_YAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=_xDC7_YAAAAJ',
#   'name': 'Małgorzata Rutkowska',
# ...
#   'interests': [],
#   'citedby': 8},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'nuuvkqsAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nuuvkqsAAAAJ',
#   'name': 'Bogusz Przybysławski',
#   'affiliation': 'Institute of industrial Engineering and Management, Wrocław University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Operations research'],
#   'citedby': 7},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'IHUX0JoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=IHUX0JoAAAAJ',
#   'name': 'Marcin Wesołowski',
#   'affiliation': 'PhD student, Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': [],
#   'citedby': 7},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'KS7U71AAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=KS7U71AAAAAJ',
#   'name': 'Agata Hajda',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Fluorescent probes',
#    'organic dyes',
#    'nanoparticles',
#    'amyloid formation',
#    '2PM'],
#   'citedby': 7},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '4VF4X98AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4VF4X98AAAAJ',
#   'name': 'Michał Obłąk',
#   'affiliation': 'PhD Student, Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Photovoltaics',
#    'Semiconductors',
#    'Microelectronics',
#    'MEMS',
#    'Atomic Force Microscopy'],
#   'citedby': 6},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'p-BdNYsAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=p-BdNYsAAAAJ',
#   'name': 'Natalia Pelczar',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 6},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'o3t23asAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=o3t23asAAAAJ',
#   'name': 'Adrian Popiel',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['Sentiment analysis', 'relational learning', 'classification'],
#   'citedby': 5},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'lqtf9QkAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=lqtf9QkAAAAJ',
#   'name': 'Natalia Walerysiak',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 5},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '0eCTkSkAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0eCTkSkAAAAJ',
#   'name': 'Violetta Cymbała',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['zarządzanie w ochronie zdrowia',
#    'dokumentacja medyczna',
#    'optymalizacja'],
#   'citedby': 4},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'G35XKr0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=G35XKr0AAAAJ',
#   'name': 'Mateusz Kucharski',
#   'affiliation': 'Doktorant, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['speech acoustics',
#    'machine learning',
#    'artificial neural networks',
#    'speaker recognition'],
#   'citedby': 4},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'c2mNLm0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=c2mNLm0AAAAJ',
#   'name': 'Adrianna Filipiak - Kaczmarek',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 4},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '9-c-2esAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=9-c-2esAAAAJ',
#   'name': 'Mariusz Korzeń',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Transport szynowy',
#    'sieci transportowe',
#    'transport zbiorowy',
#    'optymalizacja sieci transportowych'],
#   'citedby': 4},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'pPskhegAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=pPskhegAAAAJ',
#   'name': 'Angelika Kosieradzka',
#   'affiliation': 'Ph. D., Wroclaw University of Technology',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 4},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'bBiSmVoAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=bBiSmVoAAAAJ',
#   'name': 'Maciej Roszak',
#   'affiliation': 'Doktorant, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['balistyka',
#    'dynamiczne zachowanie materiałów',
#    'udar',
#    'wytrzymałość materiałów',
#    'MES'],
#   'citedby': 4},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'oMtGlWgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=oMtGlWgAAAAJ',
#   'name': 'Maciej Gruszka',
#   'affiliation': 'Ph.D. student, Wroclaw University of Technology',
#   'email_domain': '@pwr.wroc.pl',
#   'interests': ['magnetron sputtering', 'thin films', 'diamond-like carbon'],
#   'citedby': 3},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'sxaJvToAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=sxaJvToAAAAJ',
#   'name': 'Łukasz Gądek',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Control engineering', 'automotive'],
#   'citedby': 3},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'SofyLKEAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=SofyLKEAAAAJ',
#   'name': 'Adrian Galeziowski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['autofocusing algorithms'],
#   'citedby': 3},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'KMn_P9MAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=KMn_P9MAAAAJ',
#   'name': 'Krzysztof W Zuber',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Komunikacja zwierząt'],
#   'citedby': 3},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'FF1D2HsAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=FF1D2HsAAAAJ',
#   'name': 'Artur Balsam',
#   'affiliation': 'Wroclaw University of Science and Technology (Politechnika Wrocławska)',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 3},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'LQlf10gAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=LQlf10gAAAAJ',
#   'name': 'Lisa Noor Arida',
#   'affiliation': 'Wroclaw University of Technology',
#   'email_domain': '@student.pwr.edu.pl',
#   'interests': ['big data'],
#   'citedby': 2},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'quZYh30AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=quZYh30AAAAJ',
#   'name': 'Marek Sompolski',
#   'affiliation': 'doktorant, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 2},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'onpy4kgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=onpy4kgAAAAJ',
#   'name': 'Anna Małachowicz',
#   'affiliation': 'adiunkt, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['architektura', 'urbanistyka'],
#   'citedby': 1},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'KgQ14eOXMVEC',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=KgQ14eOXMVEC',
#   'name': 'Bartłomiej Alberski',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['semantyka leksykalna',
#    'wordnet',
#    'nlp',
#    'teoria tekstu',
#    'zaimek'],
#   'citedby': 1},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '8B_SIMIAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=8B_SIMIAAAAJ',
#   'name': 'Zuzanna Hazubska',
#   'affiliation': 'nauczycielka akademicka, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['przywództwo',
#    'szkoła wyższa jako organizacja',
#    'zarządzanie zasobami ludzkimi'],
#   'citedby': 1},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'k2qse7YAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=k2qse7YAAAAJ',
#   'name': 'Julia Pruchnik',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Pomiary elektryczne', 'elektrochemiczna pompa ciepła'],
#   'citedby': 1},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '6kCnfUAAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=6kCnfUAAAAAJ',
#   'name': 'Aleksandra Szrek',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': [],
#   'citedby': 1},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'Zkhwj9sAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Zkhwj9sAAAAJ',
#   'name': 'Tomasz Nowak',
#   'affiliation': 'Wrocław University of Technology, PhD student',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Loudspeakers', 'Loudspeaker systems', 'Acoustics']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'OZl9QXgAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=OZl9QXgAAAAJ',
#   'name': 'Amin Ramezantitkanloo',
#   'affiliation': 'Doktorant, Politechnika Wroclawska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Steel structures', 'concrete structures', 'finite element']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'TFKZtDcAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=TFKZtDcAAAAJ',
#   'name': 'Radosław Szewczyk',
#   'affiliation': 'Doktorant,  Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Computer Aided Design (CAD)',
#    'Model Based Enterprise (MBE)']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'jmA_STMAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=jmA_STMAAAAJ',
#   'name': 'Dominik Kupisz',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['AIDC', 'systemy automatycznej identyfikacji', 'ANSI']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'OerF6tcAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=OerF6tcAAAAJ',
#   'name': 'Kinga Skrzek',
#   'affiliation': 'Doktorantka, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Technologie przyrostowe']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'oIWUYzsAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=oIWUYzsAAAAJ',
#   'name': 'Grzegorz Kaczmarczyk',
#   'affiliation': 'Doktorant, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['automatics',
#    'electronics',
#    'electric drives',
#    'artificial intelligence',
#    'neural networks']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'P8RYjF0AAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=P8RYjF0AAAAJ',
#   'name': 'Dawid Migacz',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['Knowledge distillation']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'f2fULXwAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=f2fULXwAAAAJ',
#   'name': 'Weronika Jakubowska',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['deep learning',
#    'representation learning',
#    'generative models']},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'qRHlgNYAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=qRHlgNYAAAAJ',
#   'name': 'Władysław Kopczyński',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': []},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': 'hzyOahcAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=hzyOahcAAAAJ',
#   'name': 'Kinga Sekuła',
#   'affiliation': 'Doktorant, Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': []},
#  {'container_type': 'Author',
#   'filled': [],
#   'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#   'scholar_id': '5uhhQWQAAAAJ',
#   'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=5uhhQWQAAAAJ',
#   'name': 'Paweł Skotnicki',
#   'affiliation': 'Politechnika Wrocławska',
#   'email_domain': '@pwr.edu.pl',
#   'interests': ['High Voltage Engineering', 'Dielectric Materials']}]
